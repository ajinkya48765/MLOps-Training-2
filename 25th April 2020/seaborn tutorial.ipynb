# %%
import seaborn as sb

# %%
sb.set()

# %%
dataset = sb.load_dataset('tips')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
dataset.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
dataset.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
bill = dataset['total_bill']
tip = dataset['tip']

# %%
sb.distplot(bill , color = "coral")

# %%
sb.jointplot(x = tip , y = bill , color='darkblue', kind="hex")

# %%
sb.jointplot(x = tip , y = bill , color='black', kind="reg")

# %%
bill_tip = dataset[['total_bill', 'tip', 'sex']]

# %%
sb.pairplot(dataset , hue = 'sex' , palette= "cubehelix")
